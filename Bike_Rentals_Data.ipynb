# %% [markdown]
# # Project: Bike Rental Demand Analysis

# %% [markdown]
# ### Overview
# In this project there is basic analysis of the bike rental dataset.
# We explore key statistics, check for missing values, and visualize trends in bike rentals.

# %% [markdown]
# Import Libraries

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %% [markdown]
# ## Step 1: Load Dataset

# %%
#mounting drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset
file_path = '/content/drive/MyDrive/ColabNotebooks/Anudip/Projects/SellBikeData.csv'
df = pd.read_csv(file_path, encoding='ISO-8859-1')

# %% [markdown]
# ## Step 2: Basic Information
# We display an overview of the dataset, including column names, data types, and missing values.

# %%
# Basic Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       8760 non-null   object
#  1   Rented Bike Count          8760 non-null   int64
#  2   Hour                       8760 non-null   int64
#  3   Temperature(°C)            8760 non-null   float64
#  4   Humidity(%)                8760 non-null   int64
#  5   Wind speed (m/s)           8760 non-null   float64
#  6   Visibility (10m)           8760 non-null   int64
#  7   Dew point temperature(°C)  8760 non-null   float64
#  8   Solar Radiation (MJ/m2)    8760 non-null   float64
#  9   Rainfall(mm)               8760 non-null   float64
#  10  Snowfall (cm)              8760 non-null   float64
#  11  Seasons                    8760 non-null   object
#  12  Holiday                    8760 non-null   object
# ...

# %% [markdown]
# ## Step 3: Display First Few Rows
# Checking the first five rows to understand the structure of the data.

# %%
# Display First Few Rows
df.head()
# Out:
#          Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %% [markdown]
# ## Step 4: Checking for Missing Values
# We check if any columns have missing values.

# %%
# Checking Missing Values
df.isnull().sum()
# Out:
# Date                         0
# Rented Bike Count            0
# Hour                         0
# Temperature(°C)              0
# Humidity(%)                  0
# Wind speed (m/s)             0
# Visibility (10m)             0
# Dew point temperature(°C)    0
# Solar Radiation (MJ/m2)      0
# Rainfall(mm)                 0
# Snowfall (cm)                0
# Seasons                      0
# Holiday                      0
# Functioning Day              0
# dtype: int64

# %% [markdown]
# ## Step 5: Basic Statistics
# Displaying summary statistics for numerical columns.

# %%
# Basic Statistics
df.describe()
# Out:
#        Rented Bike Count         Hour  Temperature(°C)  Humidity(%)  \
# count        8760.000000  8760.000000      8760.000000  8760.000000
# mean          704.602055    11.500000        12.882922    58.226256
# std           644.997468     6.922582        11.944825    20.362413
# min             0.000000     0.000000       -17.800000     0.000000
# 25%           191.000000     5.750000         3.500000    42.000000
# 50%           504.500000    11.500000        13.700000    57.000000
# 75%          1065.250000    17.250000        22.500000    74.000000
# max          3556.000000    23.000000        39.400000    98.000000
#
#        Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# count       8760.000000       8760.000000                8760.000000
# mean           1.724909       1436.825799                   4.073813
# std            1.036300        608.298712                  13.060369
# min            0.000000         27.000000                 -30.600000
# ...

# %% [markdown]
# ## Step 6: Visualizing Duplicate Values
# A bar chart showing duplicate Values in the data.

# %%
# Visualizing the duplicate values
plt.figure(figsize=(8,5))
#assigning the fig size to this countplot
#For better Well-structured and code formatted we will use (8,5) fig size to evry chart

sns.countplot(x=df.duplicated())
plt.title('Visualisation of duplicated value')
plt.ylabel('Duplicate Values')
plt.show()

# %% [markdown]
# ### What information is provided by this dataset?

# %% [markdown]
# 1.   #### There are a total of 14 feature columns where Rented_Bike_Count is the dependent variable column.
# 2.   #### The total number of observations(rows) are 8760.
# 3. #### There are no duplicate rows in the dataset.
# 4. #### Also there are no missing values or Null values in the dataset.
# 5. #### Date- columns need to convert into proper data type.
# 6. #### Columns to convert into numeric(for modelling Purpose)
# seasons
# holiday
# functioning day

# %% [markdown]
# ## Step 7: Visualizing Rentals Per Hour
# A bar chart showing how bike rentals vary throughout the day.

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=df['Hour'], y=df['Rented Bike Count'], ci=None)
plt.xlabel("Hour of the Day")
plt.ylabel("Bike Rentals")
plt.title("Bike Rentals Per Hour")
plt.show()
# Out:
# <ipython-input-9-db41f8b659e9>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df['Hour'], y=df['Rented Bike Count'], ci=None)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To see how rented bike demand is distributed over 24 hours time we used Bar plot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above line plot we can clearly see that there is high demand in the morning and in the evening.

# %% [markdown]
# ## Step 8: Correlation Heatmap
# A heatmap to understand relationships between different variables.

# %%
# Convert 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# Select only numeric columns for correlation
numeric_df = df.select_dtypes(include=['number'])

# Generate heatmap
plt.figure(figsize=(10, 5))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# the correlation between all the variables along with the correlation coeficients, i have used correlation heatmap.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Temperature and Dew point Temperature are highly correlated.
# As per our regression assumption, there should not be colinearity between independent variables.
# We can see from the heatmap that "Temperature" and "Dew Point Temperature" are highly corelated. We can drop one of them.As the corelation between temperature and our dependent variable "Bike Rented Count" is high. So we will Keep the Temperature column and drop the "Dew Point Temperature" column.

# %% [markdown]
# ## Step 9: Visualizing Bike Rentals By Season
# Checking whether bike rentals are higher or lower in specific season.

# %%
#Calculate total rentals per season
Winter=df[df["Seasons"]=='Winter']["Rented Bike Count"].sum()
Spring=df[df["Seasons"]=='Spring']["Rented Bike Count"].sum()
Summer=df[df["Seasons"]=='Summer']["Rented Bike Count"].sum()
Autumn=df[df["Seasons"]=='Autumn']["Rented Bike Count"].sum()


#Store Rentals in Dictionary by making list
BikeSeasons = {"Winter": Winter, "Spring": Spring, "Summer": Summer, "Autumn": Autumn}

#Create and Display the Pie Chart
plt.gcf().set_size_inches(10,10)
plt.pie(BikeSeasons.values(),labels=BikeSeasons.keys(), autopct='%1d%%');
plt.title("Repartition of bikes rental by season", fontsize=20)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To do a multivariate analysis among Hour, Rented Bike Count and Months

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# People prefer renting bikes most in the Summer season and the least in winter season.

# %% [markdown]
# ## Step 10: Visualizing Rented Bike count

# %%
plt.figure(figsize=(11,6))
plt.title('Rented Bike Count')
sns.distplot(df ['Rented Bike Count'] )
plt.show()
# Out:
# <ipython-input-27-703acb8e352c>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df ['Rented Bike Count'] )

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **To show the data distribution Displot is best.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **From above distribution plot of dependent variable rented bike, we can clearly see that the distribution is positively skewed (Right skewed).It means that distribution is not symmetric around the the mean.**

# %% [markdown]
# ### **Conclusion**

# %% [markdown]
# 1. We found that people rent bikes the most in the morning and evening
#    when they travel for work.
# 2. When the temperature is too high or humidity is more, fewer people
#    rent bikes.
# 3. On weekends, more people rent bikes, which means they use them for
#    fun or outings.
# 4. We observed that weather, time of the day, and working hours affect
#    bike rentals a lot.
# 5. If bikes are made available more during busy hours and good weather,
#    people can use them better.
